# %%
import os
import playsound
import speech_recognition as sr
from gtts import gTTS
import time
import random

def speak(text):
    tts = gTTS(text=text, lang="en")
    filename = "voice8.mp3"
    tts.save(filename)
    playsound.playsound(filename)
    os.remove(filename)


def get_audio():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        audio = r.listen(source)
        said = ""

        try:
            said = r.recognize_google(audio)
            print(said)
        except Exception as e:
            print("sorry please repeat " + str(e))

    return said

text = get_audio()
if "alpha" in text:
    speak("yeah sir how can i help you?")


if "hello" in text:
    
    greetings = [f"hey how are, how can I help you ayoub ", f"hey are you, what's up? sir ", f"I'm listening ", f"how can I help you? ayoub", f"hello ayoub"]
    greet = greetings[random.randint(0,len(greetings)-1)]
    speak(greet)
    
elif "what is your name" in text:
    speak("My name is Tim")
if "good night" in text:
    speak("good night ayoub, take care you need to wake up early to morrow you have many things to be done")
# Out:
# what is your name

# %%
import os
import playsound
import speech_recognition as sr
from gtts import gTTS
import time
import random

def speak(text):
    tts = gTTS(text=text, lang="en")
    filename = "voice8.mp3"
    tts.save(filename)
    playsound.playsound(filename)
    os.remove(filename)


def get_audio():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        audio = r.listen(source)
        said = ""

        try:
            said = r.recognize_google(audio)
            print(said)
        except Exception as e:
            print("sorry please repeat " + str(e))

    return said

text = get_audio()
if "alpha" in text:
    speak("yeah sir how can i help you?")

def execute_voice(text):
    if "hello" in text:
        hi=get_audio('hi how are you boss how can i help you ?')
        speak(' in one minute sir')
    if "what is your name" in text:
        speak("My name is Tim")
    if "good night" in text:
        speak("good night ayoub, take care you need to wake up early to morrow you have many things to be done")
# Out:
# hello

# %%
import speech_recognition as sr
from gtts import gTTS
import playsound
import os
import weathercom
import json


r = sr.Recognizer()

def voice_command_processor(ask=False):
    with sr.Microphone() as source:
        if(ask):
            audio_playback(ask)
        audio = r.listen(source,phrase_time_limit=4)
        text = ''
        try:
            text=r.recognize_google(audio)
        except sr.UnknownValueError as e:
            print(e)
        except sr.RequestError as e:
            print("service is down")

        return text.lower()



def audio_playback(text):
    filename = "test.mp3"
    tts = gTTS(text=text, lang='en')
    tts.save(filename)
    playsound.playsound(filename)
    os.remove(filename)


def execute_voice_command(text):
    if "hello amanda" in text:
        audio_playback("hi sir how can i help you")
    if "tell me my name" in text:
        audio_playback("from your voice i think you are ayoub")
    if"how many brothers i have" in text:
        audio_playback("you have sir one brother and one sister")

    if "tell me about the weather" in text:
        city = voice_command_processor("witch city")
        humidity, temp, phrase = weatherReport(city)
        audio_playback("currently in " + city + "  temperature is " + str(temp)
                       + " degree celsius, " + "humidity is " + str(humidity) + " percent and sky is " + phrase)
        print("currently in " + city + "  temperature is " + str(temp)
              + "degree celsius, " + "humidity is " + str(humidity) + " percent and sky is " + phrase)
    if"goodbye" in text:
        audio_playback("a dios, see you later, i'm here to serve you any time you want")
        
        

    

def weatherReport(city):
    weatherDetails = weathercom.getCityWeatherDetails(city)
    humidity = json.loads(weatherDetails)["vt1observation"]["humidity"]
    temp = json.loads(weatherDetails)["vt1observation"]["temperature"]
    phrase = json.loads(weatherDetails)["vt1observation"]["phrase"]
    return humidity, temp, phrase


while True:
    command = voice_command_processor()
    print(command)
    execute_voice_command(command)
